# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime as dt
import time

# %%
url = "https://public.coindcx.com/market_data/trade_history?pair=B-BTC_USDT&interval=1m&limit=500"

# %%
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9249b3f4cf4b> in <cell line: 1>()
# ----> 1 response = requests.get(url)
#       2 data = response.json()
#       3 df = pd.DataFrame(data)
#       4 print(df)
#
# NameError: name 'requests' is not defined

# %%
df['date_time'] = df['T'].apply(lambda x : time.strftime("%Y-%m-%d %H:%M:%M",time.localtime(int(str(x)[:-3]))))

# %%
df.reset_index(drop=True)
# Out:
#             p        q        s              T      m            date_time
# 0    61766.16  0.00311  BTCUSDT  1715530698718   True  2024-05-12 16:18:18
# 1    61766.16  0.00073  BTCUSDT  1715530698477   True  2024-05-12 16:18:18
# 2    61766.17  0.00016  BTCUSDT  1715530698455  False  2024-05-12 16:18:18
# 3    61766.16  0.00273  BTCUSDT  1715530698287   True  2024-05-12 16:18:18
# 4    61766.16  0.00327  BTCUSDT  1715530697708   True  2024-05-12 16:18:18
# ..        ...      ...      ...            ...    ...                  ...
# 495  61749.13  0.00685  BTCUSDT  1715530664865   True  2024-05-12 16:17:17
# 496  61749.13  0.00542  BTCUSDT  1715530664863   True  2024-05-12 16:17:17
# 497  61749.14  0.00008  BTCUSDT  1715530664691  False  2024-05-12 16:17:17
# 498  61749.14  0.00013  BTCUSDT  1715530664678  False  2024-05-12 16:17:17
# 499  61749.14  0.06203  BTCUSDT  1715530664198  False  2024-05-12 16:17:17
#
# [500 rows x 6 columns]

# %%
df = df[['date_time','p','q','s','m']]

# %%
df_final = df.sort_values('p',ascending = False).head(20)

# %%
df_final.rename(columns = {'date_time':'Date Time','p':'Price','q':'Quantity','s':'Market Name','m':'Market Maker'}, inplace = True)

# %%
df_final
# Out:
#               Date Time     Price  Quantity Market Name  Market Maker
# 74  2024-05-12 16:18:18  61775.93   0.00725     BTCUSDT         False
# 63  2024-05-12 16:18:18  61775.93   0.00011     BTCUSDT         False
# 71  2024-05-12 16:18:18  61775.93   0.00147     BTCUSDT         False
# 70  2024-05-12 16:18:18  61775.93   0.04097     BTCUSDT         False
# 69  2024-05-12 16:18:18  61775.93   0.00044     BTCUSDT         False
# 66  2024-05-12 16:18:18  61775.92   0.00009     BTCUSDT          True
# 73  2024-05-12 16:18:18  61775.92   0.00818     BTCUSDT          True
# 68  2024-05-12 16:18:18  61775.92   0.00060     BTCUSDT          True
# 67  2024-05-12 16:18:18  61775.92   0.00029     BTCUSDT          True
# 72  2024-05-12 16:18:18  61775.92   0.00019     BTCUSDT          True
# 65  2024-05-12 16:18:18  61775.92   0.00028     BTCUSDT          True
# 58  2024-05-12 16:18:18  61775.92   0.01112     BTCUSDT          True
# ...

# %%
coinDCX = '/content/drive/MyDrive/Grull/Report.gsheet'

# %%
#pip install gsheet-pandas
#!pip install gspread-dataframe
#!pip install --upgrade gspread

# %%
import gsheet_pandas
from gspread_dataframe import get_as_dataframe, set_with_dataframe
import gspread

# %%
GSHEET_NAME = 'Report'
TAB_NAME = 'Coindcx'

# %%
def write_to_sheet(GSHEET_NAME,TAB_NAME,df):
  gc = gspread.service_account(filename='/content/drive/MyDrive/Grull/cryptocurrencies-423115-6dc2eba305ca.json')
  sh = gc.open(GSHEET_NAME)
  worksheet = sh.worksheet(TAB_NAME)
  set_with_dataframe(worksheet,df)

# %%
write_to_sheet(GSHEET_NAME,TAB_NAME,df_final)
